# %% [markdown]
# Python Data Types : String , List , Tuple, Set , Dictionary

# %% [markdown]
# String : a sequence of characters enclosed in single quotes (' ') or double quotes (" ").

# %%
text = "Python"

print(text)
print(text[0])      # P
print(len(text))    # 6
# Out:
# Python
# P
# 6

# %% [markdown]
# List: stores multiple values in one variable
# Common Methods:
# append(),
# insert(),
# remove(),
# pop(),
# sort(),
# reverse()

# %%
fruits = ["Kiwi","Banana", "Orange"]

print(fruits)
print(fruits[1])

fruits.append("Mango")
print(fruits)
# Out:
# ['Kiwi', 'Banana', 'Orange']
# Banana
# ['Kiwi', 'Banana', 'Orange', 'Mango']

# %% [markdown]
# Tuple:similar to a list but cannot be modified after creation.

# %%
numbers = (10,20,30)

print(numbers)
print(numbers[0])
# Out:
# (10, 20, 30)
# 10

# %% [markdown]
# Set: A set stores unique value

# %%
colors = {"Red","Blue","Green","Red"}

print(colors)
# Out:
# {'Green', 'Blue', 'Red'}

# %% [markdown]
# Dict: A dictionary stores data as key-value pairs.

# %%
student = {
    "name":"John",
    "age":22
}

print(student["name"])
# Out:
# John

# %% [markdown]
# Loop -A loop repeats a block of code multiple times until a condition becomes false or all items have been processed.

# %% [markdown]
# For Loop : A for loop is used when you know how many times you want to repeat something or when you want to iterate through a sequence (list, string, tuple, range, etc.).

# %%
fruits = ["Apple","Banana","Orange"]

for fruit in fruits:
    print(fruit)
# Out:
# Apple
# Banana
# Orange

# %% [markdown]
# While loop: A while loop repeats as long as a condition is True.

# %%
count = 1

while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Range : generates the sequence of numbers. commonly used for loop

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(2,11,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
#Reverse a string
text = "Python"

print(text[::-1])
# Out:
# nohtyP

# %%
#Reverse a string using loop 
text = "Python"
reverse = ""

for char in text:
    reverse= char + reverse
print(reverse)

# %% [markdown]
# Count  variable :count variable keeps track of how many times something happens.

# %%
count = 1

while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Break statement : immediately stops the loop, even if the loop condition is still true.

# %%
for i in range(10):

    if i == 5:
        break

    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %% [markdown]
# Continue statement :  statement we can stop the current iteration, and continue with the next:

# %%
i = 0
while i < 6:
  i += 1
  if i == 3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %% [markdown]
# Else: statement we can run a block of code once when the condition no longer is true:

# %%
i = 1
while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6
